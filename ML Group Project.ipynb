# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
listings = pd.read_csv("listings.csv.gz")
listings
# Out:
#                        id                                       listing_url  \
# 0                    6606                 https://www.airbnb.com/rooms/6606
# 1                    9419                 https://www.airbnb.com/rooms/9419
# 2                    9596                 https://www.airbnb.com/rooms/9596
# 3                   11012                https://www.airbnb.com/rooms/11012
# 4                   25002                https://www.airbnb.com/rooms/25002
# ...                   ...                                               ...
# 6991  1515445606707131986  https://www.airbnb.com/rooms/1515445606707131986
# 6992  1515452490876536616  https://www.airbnb.com/rooms/1515452490876536616
# 6993  1516340815301554136  https://www.airbnb.com/rooms/1516340815301554136
# 6994  1516722602078881683  https://www.airbnb.com/rooms/1516722602078881683
# 6995  1516825888737631052  https://www.airbnb.com/rooms/1516825888737631052
#
#            scrape_id last_scraped           source  \
# ...

# %% [markdown]
# feature interested
# - Keys: id, scrape_id
# - Marketing: name (text), description (text)
# - Location: neighborhood_overview (text), neighbourhood_cleansed (categorical) latitude, longtitude (enables to joing the data with seattle geo datasets of crime or any datasets related to travling)
# - Host: host_response_time (categorical / Ordinal), host_response_rate (%), host_is_superhost (t/f), host_has_profile_pic (t/f), host_identity_verified (t/f)
# - Housing type: property_type (entire house / private room, etc), room_type (Entire home / Private room), accommodates (numeric), bathrooms (numeric), bathrooms_text(e.g. 1 bath, 3 shared baths), bedrooms (numeric), beds (numeric), amenities (list type)
# - Booking Condition: minimum_nights (numeric, long-term / short-term type) <- ?
# - Reviews: number_of_reviews_ltm (last twelve month), number_of_review_l30d (last 30 days), review_scores_accuracy (?), review_scores_cleanliness	review_scores_checkin	review_scores_communication	review_scores_location	review_scores_value
#
# - Target Variables: price (e.g.$99.0), review_scores_rating (numeric)
#
#
# +) meaningful features for multi-modal regression (Deep Learning) or LLM
# - picture_url : evaluating if the picture affects the pricing/rating
# - host_thumbnail_url / host_picture_url : evaluating if the host picture affects the pricing/rating (e.g. thumbnail == human picture)
# - host_id / host_name / host_about : extracting the info (english name, job) and evaluating if it affects the rating

# %% [markdown]
# [Price-Focused] What Determines the Listing Price?
#
# Research Question (RQ1): "Beyond physical specifications (Beds, Bathrooms), do Host Credibility Indicators (Superhost status, Identity Verification) provide a significant premium in pricing?"
#
# Target ($y$): price (Continuous variable)Key
#
# Features ($X$):
# - Physical Attributes: room_type, accommodates, bathrooms, bedsHost
# - Credibility: host_is_superhost, host_identity_verified, host_response_rate
# - Location: neighbourhood_cleansed, latitude, longitude
